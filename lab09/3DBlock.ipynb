# %%
pip install d3blocks
# Out:
# Requirement already satisfied: d3blocks in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from d3blocks) (2.2.6)
# Requirement already satisfied: colourmap>=1.1.10 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from d3blocks) (1.2.1)
# Requirement already satisfied: datazets>=0.1.7 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from d3blocks) (1.1.3)
# Requirement already satisfied: d3graph>=2.4.16 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from d3blocks) (2.6.1)
# Requirement already satisfied: ismember>=1.0.1 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from d3blocks) (1.1.0)
# Requirement already satisfied: pandas in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from d3blocks) (2.3.3)
# Requirement already satisfied: tqdm in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from d3blocks) (4.67.1)
# Requirement already satisfied: requests in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from d3blocks) (2.32.5)
# Requirement already satisfied: jinja2 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from d3blocks) (3.1.6)
# Requirement already satisfied: matplotlib in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from colourmap>=1.1.10->d3blocks) (3.10.6)
# Requirement already satisfied: scipy in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from colourmap>=1.1.10->d3blocks) (1.16.2)
# Requirement already satisfied: networkx>2 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from d3graph>=2.4.16->d3blocks) (3.6.1)
# Requirement already satisfied: packaging in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from d3graph>=2.4.16->d3blocks) (25.0)
# Requirement already satisfied: markupsafe==2.0.1 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from d3graph>=2.4.16->d3blocks) (2.0.1)
# Requirement already satisfied: python-louvain in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from d3graph>=2.4.16->d3blocks) (0.16)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from pandas->d3blocks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from pandas->d3blocks) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from pandas->d3blocks) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from requests->d3blocks) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from requests->d3blocks) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from requests->d3blocks) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from requests->d3blocks) (2025.8.3)
# Requirement already satisfied: colorama in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from tqdm->d3blocks) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->d3blocks) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from matplotlib->colourmap>=1.1.10->d3blocks) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from matplotlib->colourmap>=1.1.10->d3blocks) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from matplotlib->colourmap>=1.1.10->d3blocks) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from matplotlib->colourmap>=1.1.10->d3blocks) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from matplotlib->colourmap>=1.1.10->d3blocks) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from matplotlib->colourmap>=1.1.10->d3blocks) (3.2.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Interaktywna wizualizacja sieci przepływów energetycznych (d3blocks)

# %%
from d3blocks import D3Blocks

# Initialize
d3 = D3Blocks()

# Import example
df = d3.import_example('energy')

# Show the input data
print(df)
#                      source            target   weight
# 0      Agricultural 'waste'    Bio-conversion  124.729
# 1            Bio-conversion            Liquid    0.597
# 2            Bio-conversion            Losses   26.862
# 3            Bio-conversion             Solid  280.322
# 4            Bio-conversion               Gas   81.144
# ..                      ...               ...      ...
# 63       Thermal generation  District heating   79.329
# 64                    Tidal  Electricity grid    9.452
# 65  UK land based bioenergy    Bio-conversion  182.010
# 66                     Wave  Electricity grid   19.013
# 67                     Wind  Electricity grid  289.366

# [68 rows x 3 columns]


# Initialize Network chart but do not yet show the chart.
d3.d3graph(df, showfig=False)

# Color node on clustering
d3.D3graph.set_node_properties(color='cluster')

# Make adjustments to the node: Thermal_generation
d3.D3graph.node_properties['Thermal_generation']['size']=20
d3.D3graph.node_properties['Thermal_generation']['edge_color']='#000fff' # Blue node edge
d3.D3graph.node_properties['Thermal_generation']['edge_size']=3 # Node-edge Size

# Make adjustments to the edge: 'Solar', 'Solar_Thermal'
d3.D3graph.edge_properties['Solar', 'Solar_Thermal']['color']='#000fff'
d3.D3graph.edge_properties['Solar', 'Solar_Thermal']['weight_scaled']=10

# Show the network graph
d3.D3graph.show()
# Out:
# [17-12-2025 12:55:57] [d3blocks.d3blocks] [INFO] Cleaning edge_properties and config parameters..
# [17-12-2025 12:55:57] [datazets.datazets] [INFO] Import dataset [energy]
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] Converting source-target into adjacency matrix..
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] Making the matrix symmetric..
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] Set directed=True to see the markers!
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] Keep only edges with weight>0
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] Converting source-target into adjacency matrix..
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] Making the matrix symmetric..
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] Converting adjacency matrix into source-target..
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] Number of unique nodes: %.0d
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] Slider range is set to [0, 840]
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] Write to path: [C:\Users\Kamil\AppData\Local\Temp\d3graph\d3graph.html]
#                      source            target   weight
# 0      Agricultural 'waste'    Bio-conversion  124.729
# 1            Bio-conversion            Liquid    0.597
# 2            Bio-conversion            Losses   26.862
# 3            Bio-conversion             Solid  280.322
# 4            Bio-conversion               Gas   81.144
# ..                      ...               ...      ...
# 63       Thermal generation  District heating   79.329
# 64                    Tidal  Electricity grid    9.452
# 65  UK land based bioenergy    Bio-conversion  182.010
# 66                     Wave  Electricity grid   19.013
# 67                     Wind  Electricity grid  289.366
#
# [68 rows x 3 columns]
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] File already exists and will be overwritten: [C:\Users\Kamil\AppData\Local\Temp\d3graph\d3graph.html]
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] Converting adjacency matrix into source-target..
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] Number of unique nodes: %.0d
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] Slider range is set to [0, 840]
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] Write to path: [C:\Users\Kamil\AppData\Local\Temp\d3graph\e8855451.html]
# [17-12-2025 12:55:57] [d3graph.d3graph] [INFO] File already exists and will be overwritten: [C:\Users\Kamil\AppData\Local\Temp\d3graph\e8855451.html]

# %% [markdown]
# # Tworzenie wykresu Sankeya z kolorowaniem przepływów według źródła i celu

# %%
from d3blocks import D3Blocks

# Initialize
d3 = D3Blocks()

# Import example
df = d3.import_example('energy')

# Link settings
d3.sankey(df, link={"color": "source-target"})
# Out:
# [17-12-2025 12:59:04] [d3blocks.d3blocks] [INFO] Cleaning edge_properties and config parameters..
# [17-12-2025 12:59:04] [datazets.datazets] [INFO] Import dataset [energy]
# [17-12-2025 12:59:04] [d3blocks.d3blocks] [INFO] Cleaning edge_properties and config parameters..
# [17-12-2025 12:59:04] [d3blocks.d3blocks] [INFO] Initializing [Sankey]
# [17-12-2025 12:59:04] [d3blocks.d3blocks] [INFO] filepath is set to [C:\Users\Kamil\AppData\Local\Temp\d3blocks\sankey.html]
# [17-12-2025 12:59:04] [d3blocks.d3blocks] [INFO] Convert to DataFrame.
# [17-12-2025 12:59:04] [d3blocks.d3blocks] [INFO] Node properties are set.
# [17-12-2025 12:59:04] [d3blocks.d3blocks] [INFO] Edge properties are set.
# [17-12-2025 12:59:04] [d3blocks.d3blocks] [INFO] File already exists and will be overwritten: [C:\Users\Kamil\AppData\Local\Temp\d3blocks\sankey.html]
# [17-12-2025 12:59:05] [d3blocks.d3blocks] [INFO] Open browser: C:\Users\Kamil\AppData\Local\Temp\d3blocks\sankey.html

# %% [markdown]
# ## Tworzenie wykresu Chorda i zapisywanie go do pliku HTML

# %%
from d3blocks import D3Blocks

# Initialize
d3 = D3Blocks()

# Import example
df = d3.import_example('energy')

# Link settings
d3.chord(df, filepath='chord_demo.html')
# Out:
# [17-12-2025 12:59:18] [d3blocks.d3blocks] [INFO] Cleaning edge_properties and config parameters..
# [17-12-2025 12:59:18] [datazets.datazets] [INFO] Import dataset [energy]
# [17-12-2025 12:59:18] [d3blocks.d3blocks] [INFO] Cleaning edge_properties and config parameters..
# [17-12-2025 12:59:18] [d3blocks.d3blocks] [INFO] Initializing [Chord]
# [17-12-2025 12:59:18] [d3blocks.d3blocks] [INFO] filepath is set to [C:\Users\Kamil\AppData\Local\Temp\d3blocks\chord_demo.html]
# [17-12-2025 12:59:18] [d3blocks.d3blocks] [INFO] Convert to DataFrame.
# [17-12-2025 12:59:18] [d3blocks.d3blocks] [INFO] Node properties are set.
# [17-12-2025 12:59:18] [d3blocks.d3blocks] [INFO] Set edge-opacity based on the [source] node-opacity.
# [17-12-2025 12:59:18] [d3blocks.d3blocks] [INFO] Set edge-colors based on the [source] node-color.
# [17-12-2025 12:59:18] [d3blocks.d3blocks] [INFO] Edge properties are set.
# [17-12-2025 12:59:18] [d3blocks.d3blocks] [INFO] File already exists and will be overwritten: [C:\Users\Kamil\AppData\Local\Temp\d3blocks\chord_demo.html]
# [17-12-2025 12:59:19] [d3blocks.d3blocks] [INFO] Open browser: C:\Users\Kamil\AppData\Local\Temp\d3blocks\chord_demo.html

# %% [markdown]
# # Tworzenie wykresu szeregów czasowych dla danych klimatycznych

# %%
# Import library.
from d3blocks import D3Blocks

# Initialize and set the datetime format
d3 = D3Blocks()

# Import climate dataset
df = d3.import_example('climate')

# Print
df.head()

#            date   meantemp   humidity  wind_speed  meanpressure
#     2017-01-01  15.913043  85.869565    2.743478     59.000000
#     2017-01-02  18.500000  77.222222    2.894444   1018.277778
#     2017-01-03  17.111111  81.888889    4.016667   1018.333333
#     2017-01-04  18.700000  70.050000    4.545000   1015.700000
#     2017-01-05  18.388889  74.944444    3.300000   1014.333333
#           ...        ...        ...         ...           ...
#     2017-04-20  34.500000  27.500000    5.562500    998.625000
#     2017-04-21  34.250000  39.375000    6.962500    999.875000
#     2017-04-22  32.900000  40.900000    8.890000   1001.600000
#     2017-04-23  32.875000  27.500000    9.962500   1002.125000
#     2017-04-24  32.000000  27.142857   12.157143   1004.142857

# [114 rows x 5 columns]

# Create the timeseries chart.
d3.timeseries(df, datetime='date', dt_format='%Y-%m-%d', fontsize=10)
# Out:
# [17-12-2025 13:00:25] [d3blocks.d3blocks] [INFO] Cleaning edge_properties and config parameters..
# [17-12-2025 13:00:25] [d3blocks.d3blocks] [INFO] Extracting files..
# [17-12-2025 13:00:25] [d3blocks.d3blocks] [INFO] Import dataset: [climate]
# [17-12-2025 13:00:25] [d3blocks.d3blocks] [INFO] Initializing [Timeseries]
# [17-12-2025 13:00:25] [d3blocks.d3blocks] [INFO] filepath is set to [C:\Users\Kamil\AppData\Local\Temp\d3blocks\timeseries.html]
# [17-12-2025 13:00:25] [d3blocks.d3blocks] [INFO] Convert to DataFrame.
# [17-12-2025 13:00:25] [d3blocks.d3blocks] [INFO] Node properties are set.
# [17-12-2025 13:00:25] [d3blocks.d3blocks] [INFO] Edge properties are set.
# [17-12-2025 13:00:25] [d3blocks.d3blocks] [INFO] File already exists and will be overwritten: [C:\Users\Kamil\AppData\Local\Temp\d3blocks\timeseries.html]
# [17-12-2025 13:00:26] [d3blocks.d3blocks] [INFO] Open browser: C:\Users\Kamil\AppData\Local\Temp\d3blocks\timeseries.html

# %% [markdown]
# # Tworzenie interaktywnego wykresu „moving bubbles” dla losowych danych czasowych

# %%
# Import library
from d3blocks import D3Blocks

# Set color scheme
d3 = D3Blocks()

# Generate random data with various states
df = d3.import_example('random_time', n=10000, c=500, date_start="1-1-2000 00:10:05", date_stop="1-1-2001 23:59:59")

#                 datetime sample_id     state
# 0    2000-01-01 00:10:10        54  Hospital
# 1    2000-01-01 00:10:19        28      Home
# 2    2000-01-01 00:10:21        98  Hospital
# 3    2000-01-01 00:10:30        12  Hospital
# 4    2000-01-01 00:10:32        71    Travel
#                  ...       ...       ...
# 9995 2000-01-01 23:59:20         2  Hospital
# 9996 2000-01-01 23:59:24        17      Home
# 9997 2000-01-01 23:59:31        37     Bored
# 9998 2000-01-01 23:59:47        48     Sport
# 9999 2000-01-01 23:59:47        70    Travel

# [10000 rows x 3 columns]

# Make the moving bubbles chart.
d3.movingbubbles(df,
                 datetime='datetime',
                 state='state',
                 sample_id='sample_id',
                 standardize=None,
                 speed={"slow": 1000, "medium": 200, "fast": 10},
                 cmap='Set1',
                 filepath='movingbubbles.html')
# Out:
# [17-12-2025 12:51:10] [d3blocks.d3blocks] [INFO] Cleaning edge_properties and config parameters..
# [17-12-2025 12:51:14] [d3blocks.d3blocks] [INFO] Cleaning edge_properties and config parameters..
# [17-12-2025 12:51:14] [d3blocks.d3blocks] [INFO] Initializing [Movingbubbles]
# [17-12-2025 12:51:14] [d3blocks.d3blocks] [INFO] filepath is set to [C:\Users\Kamil\AppData\Local\Temp\d3blocks\movingbubbles.html]
# [17-12-2025 12:51:14] [d3blocks.d3blocks] [INFO] Convert to DataFrame.
# [17-12-2025 12:51:14] [d3blocks.d3blocks] [INFO] Node properties are set.
# [17-12-2025 12:51:14] [d3blocks.d3blocks] [INFO] Standardizing input dataframe using method: [None].
# [17-12-2025 12:51:14] [d3blocks.d3blocks] [INFO] Set all nodes to size: 5
# [17-12-2025 12:51:14] [colourmap.colourmap] [WARNING] Colormap [Set1] can not create [500] unique colors! Available unique colors: [9].
# [17-12-2025 12:51:14] [d3blocks.d3blocks] [INFO] Edge properties are set.
# [17-12-2025 12:51:15] [d3blocks.d3blocks] [INFO] File already exists and will be overwritten: [C:\Users\Kamil\AppData\Local\Temp\d3blocks\movingbubbles.html]
# [17-12-2025 12:51:15] [d3blocks.d3blocks] [INFO] Open browser: C:\Users\Kamil\AppData\Local\Temp\d3blocks\movingbubbles.html

# %% [markdown]
# # Tworzenie interaktywnego suwaka porównującego obrazy

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\kamil\desktop\code library\semestr ix\wiz\kolejnameczarnia\.venv\lib\site-packages (from opencv-python) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import biblioteki
from d3blocks import D3Blocks

# Inicjalizacja D3Blocks
d3 = D3Blocks()

# Ścieżki do własnych obrazów (przykład Windows)
# Zamień na swoje pliki .jpg lub .png
img_before = r"C:\ścieżka\do\before.jpg"
img_after = r"C:\ścieżka\do\after.jpg"

# Wyświetlenie ścieżek w konsoli (opcjonalnie)
print("Before image:", img_before)
print("After image:", img_after)

# Utworzenie suwaka obrazów
d3.imageslider(img_before, img_after)
# Out:
# [17-12-2025 13:00:54] [d3blocks.d3blocks] [INFO] Cleaning edge_properties and config parameters..
# [17-12-2025 13:00:54] [d3blocks.d3blocks] [INFO] filepath is set to [C:\Users\Kamil\AppData\Local\Temp\d3blocks\imageslider.html]
# [17-12-2025 13:00:54] [d3blocks.d3blocks] [INFO] File already exists and will be overwritten: [C:\Users\Kamil\AppData\Local\Temp\d3blocks\imageslider.html]
# Before image: C:\ścieżka\do\before.jpg
# After image: C:\ścieżka\do\after.jpg
# [17-12-2025 13:00:55] [d3blocks.d3blocks] [INFO] Open browser: C:\Users\Kamil\AppData\Local\Temp\d3blocks\imageslider.html

# %% [markdown]
# # Tworzenie interaktywnego wykresu punktowego (scatter) dla danych nowotworowych

# %%
# Import biblioteki
from d3blocks import D3Blocks
import numpy as np

# Inicjalizacja
d3 = D3Blocks()

# Import datasetu "cancer"
df = d3.import_example('cancer')

# Kolumna z etykietami (tu 'death_indicator')
label_col = 'death_indicator'

# Tooltip: etykieta + survival_months
tooltip = df[label_col].astype(str).values + ' <br /> Survival: ' + df['survival_months'].fillna(0).astype(str).str[:4].values

# Rozmiar punktów
size = df['survival_months'].fillna(1).values / 10

# Kolory: konwertujemy etykiety na string (kategorie)
color = df[label_col].astype(str).values

# Scatter plot tSNE i PCA
d3.scatter(
    df['tsneX'].values,   # tSNE x
    df['tsneY'].values,   # tSNE y
    x1=df['PC1'].values,  # PCA x
    y1=df['PC2'].values,  # PCA y
    scale=True,
    label_radio=['tSNE', 'PCA'],
    size=size,
    color=color,
    stroke='#000000',
    opacity=0.4,
    tooltip=tooltip,
    cmap='tab20',
    filepath='c://temp//scatter_demo.html'
)

print("Scatter plot zapisany do: c://temp//scatter_demo.html")
# Out:
# [17-12-2025 13:01:10] [d3blocks.d3blocks] [INFO] Cleaning edge_properties and config parameters..
# [17-12-2025 13:01:10] [datazets.datazets] [INFO] Import dataset [cancer]
# [17-12-2025 13:01:10] [d3blocks.d3blocks] [INFO] Cleaning edge_properties and config parameters..
# [17-12-2025 13:01:10] [d3blocks.d3blocks] [INFO] Initializing [Scatter]
# [17-12-2025 13:01:10] [d3blocks.d3blocks] [INFO] filepath is set to [c:\temp\scatter_demo.html]
# [17-12-2025 13:01:10] [d3blocks.d3blocks] [INFO] Scaling xy-coordinates.
# [17-12-2025 13:01:10] [d3blocks.d3blocks] [INFO] [12] sizes are <0 and set to 0.
# [17-12-2025 13:01:11] [d3blocks.d3blocks] [INFO] Set opacity based on the data density.
# [17-12-2025 13:01:11] [d3blocks.d3blocks] [INFO] Edge properties are set.
# [17-12-2025 13:01:11] [d3blocks.d3blocks] [INFO] File already exists and will be overwritten: [c:\temp\scatter_demo.html]
# [17-12-2025 13:01:12] [d3blocks.d3blocks] [INFO] Open browser: c:\temp\scatter_demo.html
# Scatter plot zapisany do: c://temp//scatter_demo.html

# %% [markdown]
# # Tworzenie wykresu skrzypcowego (violin) dla wieku pacjentów w zależności od typu nowotworu

# %%
# Import library
from d3blocks import D3Blocks

# Initialize
d3 = D3Blocks()

# import example
df = d3.import_example('cancer')

# Tooltip
tooltip=df['labels'].values + ' <br /> Survival: ' + df['survival_months'].astype(str).values

# Make the plot
d3.violin(x=df['labels'].values, # class labels on the x axis
          y=df['age'].values,    # Age
          tooltip=tooltip,       # Tooltip for hovering
          bins=50,               # Bins used for the histogram
          size=df['survival_months'].values/10, # Dotsize
          x_order=['acc','kich', 'brca','lgg','blca','coad','ov'], # Keep only these classes and plot in this order.
          figsize=[None, None],                                    # Figure size is automatically determined.
          filepath='violine_demo.html')
# Out:
# [17-12-2025 13:02:25] [d3blocks.d3blocks] [INFO] Cleaning edge_properties and config parameters..
# [17-12-2025 13:02:25] [datazets.datazets] [INFO] Import dataset [cancer]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\Code Library\Semestr IX\Wiz\KolejnaMeczarnia\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'labels'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 11
#       8 df = d3.import_example('cancer')
#      10 # Tooltip
# ---> 11 tooltip=df['labels'].values + ' <br /> Survival: ' + df['survival_months'].astype(str).values
#      13 # Make the plot
#      14 d3.violin(x=df['labels'].values, # class labels on the x axis
#      15           y=df['age'].values,    # Age
#      16           tooltip=tooltip,       # Tooltip for hovering
#    (...)     20           figsize=[None, None],                                    # Figure size is automatically determined.
#      21           filepath='violine_demo.html')
#
# File ~\Desktop\Code Library\Semestr IX\Wiz\KolejnaMeczarnia\.venv\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\Desktop\Code Library\Semestr IX\Wiz\KolejnaMeczarnia\.venv\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'labels'

# %% [markdown]
# # Tworzenie interaktywnej wizualizacji cząsteczek (particles) z tekstem

# %%
# Import library
from d3blocks import D3Blocks

# Initialize
d3 = D3Blocks()

# Make particles
d3.particles('D3Blocks', collision=0.05, spacing=10, figsize=[1200, 500])
# Out:
# [17-12-2025 13:02:28] [d3blocks.d3blocks] [INFO] Cleaning edge_properties and config parameters..
# [17-12-2025 13:02:28] [d3blocks.d3blocks] [INFO] filepath is set to [C:\Users\Kamil\AppData\Local\Temp\d3blocks\particles.html]
# [17-12-2025 13:02:28] [d3blocks.d3blocks] [INFO] Open browser: C:\Users\Kamil\AppData\Local\Temp\d3blocks\particles.html
